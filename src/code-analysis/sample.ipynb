# %%
import numpy as np
import pandas as pd

# %%
train_df = pd.read_csv('../input/train.csv')
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train_target = train_df['Survived']
train_data = train_df.drop(columns=['PassengerId', 'Survived'])

# %%
train_data['Sex'] = train_data['Sex'].astype("category")
train_data['Pclass'] = train_data['Pclass'].astype("category")
train_data['Age'] = train_data['Age'].fillna(-1)
train_data['Age'] = train_data['Age'].astype("int")
train_data['SibSp'] = train_data['SibSp'].astype("int")
train_data['Parch'] = train_data['Parch'].astype("int")
train_data['Embarked'] = train_data['Embarked'].astype("category")
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    891 non-null    category
#  1   Name      891 non-null    object
#  2   Sex       891 non-null    category
#  3   Age       891 non-null    int64
#  4   SibSp     891 non-null    int64
#  5   Parch     891 non-null    int64
#  6   Ticket    891 non-null    object
#  7   Fare      891 non-null    float64
#  8   Cabin     204 non-null    object
#  9   Embarked  889 non-null    category
# dtypes: category(3), float64(1), int64(3), object(3)
# memory usage: 51.8+ KB

# %%
train_data.groupby('Age').count()
# Out:
#      Pclass  Name  Sex  SibSp  Parch  Ticket  Fare  Cabin  Embarked
# Age
# -1      177   177  177    177    177     177   177     19       177
#  0        7     7    7      7      7       7     7      1         7
#  1        7     7    7      7      7       7     7      1         7
#  2       10    10   10     10     10      10    10      3        10
#  3        6     6    6      6      6       6     6      1         6
# ..      ...   ...  ...    ...    ...     ...   ...    ...       ...
#  66       1     1    1      1      1       1     1      0         1
#  70       3     3    3      3      3       3     3      1         3
#  71       2     2    2      2      2       2     2      1         2
#  74       1     1    1      1      1       1     1      0         1
#  80       1     1    1      1      1       1     1      1         1
#
# [72 rows x 9 columns]

# %%
train_data['Age_rank'] = (train_data['Age']//10*10).astype('category')
train_data['Fare_rank'] = (train_data['Fare']//100*100).astype('category')
train_data.head(50)
# Out:
#    Pclass                                               Name     Sex  Age  \
# 0       3                            Braund, Mr. Owen Harris    male   22
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 2       3                             Heikkinen, Miss. Laina  female   26
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 4       3                           Allen, Mr. William Henry    male   35
# 5       3                                   Moran, Mr. James    male   -1
# 6       1                            McCarthy, Mr. Timothy J    male   54
# 7       3                     Palsson, Master. Gosta Leonard    male    2
# 8       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   27
# 9       2                Nasser, Mrs. Nicholas (Adele Achem)  female   14
# 10      3                    Sandstrom, Miss. Marguerite Rut  female    4
# 11      1                           Bonnell, Miss. Elizabeth  female   58
# ...

# %%
train_data.describe()
# Out:
#               Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000
# mean    23.584736    0.523008    0.381594   32.204208
# std     17.868570    1.102743    0.806057   49.693429
# min     -1.000000    0.000000    0.000000    0.000000
# 25%      6.000000    0.000000    0.000000    7.910400
# 50%     24.000000    0.000000    0.000000   14.454200
# 75%     35.000000    1.000000    0.000000   31.000000
# max     80.000000    8.000000    6.000000  512.329200
